# %% [markdown]
# ######
# ### Enrique Mejía Fontanot
# Análisis exploratorio de la basede Carpetas de Investigación FGJ
#
# Estructura:
#
# 1. cargar bibliotecas necesarias
# 2. leer datos
# 3. limpieza y preprocesamiento
# 4. respuesta a preguntas del examen
#
# #####

# %%
##### cargar bibliotecas necesarias
import pandas as pd ## para manipular datos

# %%
#### leer datos
df = pd.read_csv('/home/patatas/Documents/examenOPI/A/input/carpetas_completa_junio_2021.csv')
# Out:
# /home/patatas/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# Revisar dimensiones del dataframe leído.

# %%
## revisar dimensiones del df
df.shape
# Out:
# (1248924, 19)

# %%
## revisar tipos de variables
df.dtypes
# Out:
# ao_hechos               float64
# mes_hechos               object
# fecha_hechos             object
# ao_inicio                 int64
# mes_inicio               object
# fecha_inicio             object
# delito                   object
# fiscalia                 object
# agencia                  object
# unidad_investigacion     object
# categoria_delito         object
# calle_hechos             object
# calle_hechos2            object
# colonia_hechos           object
# alcaldia_hechos          object
# competencia              object
# longitud                float64
# latitud                 float64
# tempo                   float64
# dtype: object

# %% [markdown]
# Notamos que contamos con un universo muy basto de datos con más de un millón de registros individuales, y con variables muy específicas que nos permiten localizar los delitos de manera temporal y espacial. Se cuenta con la fecha y hora de los hechos así como la latitud y longitud de los mismos. Además, se cuenta con el delito, la fiscalía en la que se denunció el hecho y la información sobre la competencia de la misma. Esta variable es muy importante ya que nos permite descartar correctamente los casos que no son contados como delitos

# %%
## revisar df 
df.tail()
# Out:
#          ao_hechos mes_hechos         fecha_hechos  ao_inicio mes_inicio  \
# 1248919     2021.0      Junio  2021-06-29 17:00:00       2021      Junio
# 1248920     2021.0      Junio  2021-06-04 19:00:00       2021      Junio
# 1248921     2021.0      Junio  2021-06-30 19:40:00       2021      Junio
# 1248922     2021.0       Mayo  2021-05-16 21:08:00       2021      Junio
# 1248923     2021.0      Junio  2021-06-29 17:00:00       2021      Junio
#
#                 fecha_inicio  \
# 1248919  2021-06-30 23:32:31
# 1248920  2021-06-30 23:36:45
# 1248921  2021-06-30 23:37:12
# 1248922  2021-06-30 23:45:57
# 1248923  2021-06-30 23:52:34
#
#                                                     delito  \
# 1248919  LESIONES CULPOSAS POR TRANSITO VEHICULAR EN CO...
# 1248920                         ROBO DE ACCESORIOS DE AUTO
# 1248921                                           AMENAZAS
# 1248922                DAÑO EN PROPIEDAD AJENA INTENCIONAL
# ...

# %% [markdown]
# ## limpieza y preprocesamiento

# %%
## es necesario separar la fecha y la hora de los hechos en dos variables separadas a las que les damos el nombre de _clean. 
## Es relevante notar que mantendremos esta notación de aquí en adelante con cualquier modificación similar. El motivo es conservar siempre una copia original de la
## información, en caso de requerir algún nuevo análisis.
df['fecha_hechos_clean'] = df['fecha_hechos'].str.split(' ').str.get(0)
df['hora_hechos_clean'] = df['fecha_hechos'].str.split(' ').str.get(1)

# %%
df.tail()
# Out:
#          ao_hechos mes_hechos         fecha_hechos  ao_inicio mes_inicio  \
# 1248919     2021.0      Junio  2021-06-29 17:00:00       2021      Junio
# 1248920     2021.0      Junio  2021-06-04 19:00:00       2021      Junio
# 1248921     2021.0      Junio  2021-06-30 19:40:00       2021      Junio
# 1248922     2021.0       Mayo  2021-05-16 21:08:00       2021      Junio
# 1248923     2021.0      Junio  2021-06-29 17:00:00       2021      Junio
#
#                 fecha_inicio  \
# 1248919  2021-06-30 23:32:31
# 1248920  2021-06-30 23:36:45
# 1248921  2021-06-30 23:37:12
# 1248922  2021-06-30 23:45:57
# 1248923  2021-06-30 23:52:34
#
#                                                     delito  \
# 1248919  LESIONES CULPOSAS POR TRANSITO VEHICULAR EN CO...
# 1248920                         ROBO DE ACCESORIOS DE AUTO
# 1248921                                           AMENAZAS
# 1248922                DAÑO EN PROPIEDAD AJENA INTENCIONAL
# ...
